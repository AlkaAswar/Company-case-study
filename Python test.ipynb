# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_excel('Data for 1st Quarter.xlsx')
df2 = pd.read_excel('Data for 2nd Quarter.xlsx')
df3 = pd.read_excel('Data for 3rd Quarter.xlsx')
df4 = pd.read_excel('Data for 4th Quarter.xlsx')

# %%
df1.describe()
# Out:
#         Emp_Score
# count  300.000000
# mean    54.276667
# std     28.709713
# min      1.000000
# 25%     30.000000
# 50%     56.500000
# 75%     79.000000
# max    100.000000

# %%
df1
# Out:
#     Emp_ID        Department       Date  Emp_Score
# 0      I88  Sales_South_Zone   5/5/2019         96
# 1      I50   Sales_West_Zone   4/5/2019         39
# 2      I53  Sales_South_Zone  25/5/2019         95
# 3      I48  Sales_South_Zone  24/6/2019         60
# 4      I69   Sales_West_Zone  20/4/2019         24
# ..     ...               ...        ...        ...
# 295    I26   Sales_West_Zone  20/4/2019         49
# 296    I18   Sales_West_Zone   4/6/2019         32
# 297     I8  Sales_North_Zone  24/4/2019         92
# 298    I15  Sales_South_Zone  12/5/2019         63
# 299    I93  Sales_North_Zone  22/5/2019         68
#
# [300 rows x 4 columns]

# %%
data=pd.concat([df1,df2,df3,df4],ignore_index=True,sort=False)

# %%
data
# Out:
#      Emp_ID        Department       Date  Emp_Score
# 0       I88  Sales_South_Zone   5/5/2019         96
# 1       I50   Sales_West_Zone   4/5/2019         39
# 2       I53  Sales_South_Zone  25/5/2019         95
# 3       I48  Sales_South_Zone  24/6/2019         60
# 4       I69   Sales_West_Zone  20/4/2019         24
# ...     ...               ...        ...        ...
# 1195    I59  Sales_North_Zone  19/3/2019         14
# 1196    I48  Sales_South_Zone  31/3/2019         15
# 1197    I67   Sales_East_Zone  14/2/2019         99
# 1198    I43  Sales_South_Zone  16/3/2019          3
# 1199    I25  Sales_North_Zone  22/1/2019         23
#
# [1200 rows x 4 columns]

# %%
data.info()  # No null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Emp_ID      1200 non-null   object
#  1   Department  1200 non-null   object
#  2   Date        1200 non-null   object
#  3   Emp_Score   1200 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 23.5+ KB

# %%
data['Month'] = pd.DatetimeIndex(data['Date']).month
data['Month']
data
# Out:
#      Emp_ID        Department       Date  Emp_Score  Month
# 0       I88  Sales_South_Zone   5/5/2019         96      5
# 1       I50   Sales_West_Zone   4/5/2019         39      4
# 2       I53  Sales_South_Zone  25/5/2019         95      5
# 3       I48  Sales_South_Zone  24/6/2019         60      6
# 4       I69   Sales_West_Zone  20/4/2019         24      4
# ...     ...               ...        ...        ...    ...
# 1195    I59  Sales_North_Zone  19/3/2019         14      3
# 1196    I48  Sales_South_Zone  31/3/2019         15      3
# 1197    I67   Sales_East_Zone  14/2/2019         99      2
# 1198    I43  Sales_South_Zone  16/3/2019          3      3
# 1199    I25  Sales_North_Zone  22/1/2019         23      1
#
# [1200 rows x 5 columns]

# %%
percent=data.sort_values(by="Emp_Score",ascending=False)
Top10=percent.head(10)
Top10To25=percent[10:25]
Top10
# Out:
#      Emp_ID        Department        Date  Emp_Score  Month
# 161      I7  Sales_South_Zone   13/5/2019        100      5
# 538     I21   Sales_East_Zone   20/7/2019        100      7
# 770     I88  Sales_South_Zone  26/10/2019        100     10
# 701      I7  Sales_South_Zone  20/11/2019        100     11
# 688     I26   Sales_West_Zone  30/10/2019        100     10
# 1052    I65   Sales_East_Zone   24/2/2019        100      2
# 576      I9  Sales_North_Zone   12/7/2019        100     12
# 1156    I22  Sales_North_Zone   23/1/2019        100      1
# 559     I88  Sales_South_Zone   18/8/2019        100      8
# 761     I55   Sales_West_Zone  10/12/2019        100     10

# %%
Top10['Bonus']=(Top10['Emp_Score'] * 1000)/Top10['Month']
Top10['Bonus']
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_4932/2124996688.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Top10['Bonus']=(Top10['Emp_Score'] * 1000)/Top10['Month']
# 161      20000.000000
# 538      14285.714286
# 770      10000.000000
# 701       9090.909091
# 688      10000.000000
# 1052     50000.000000
# 576       8333.333333
# 1156    100000.000000
# 559      12500.000000
# 761      10000.000000
# Name: Bonus, dtype: float64

# %%
Top10To25['Bonus']=(Top10To25['Emp_Score'] * 500)/Top10To25['Month']
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_4932/1906968378.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Top10To25['Bonus']=(Top10To25['Emp_Score'] * 500)/Top10To25['Month']

# %%
Top10To25
# Out:
#      Emp_ID        Department        Date  Emp_Score  Month         Bonus
# 864     I45  Sales_South_Zone   6/10/2019        100      6   8333.333333
# 872     I27  Sales_South_Zone  21/10/2019        100     10   5000.000000
# 939     I22  Sales_North_Zone   26/2/2019        100      2  25000.000000
# 323     I88  Sales_South_Zone   23/9/2019        100      9   5555.555556
# 1110    I22  Sales_North_Zone   27/3/2019        100      3  16666.666667
# 401      I7  Sales_South_Zone   19/9/2019         99      9   5500.000000
# 839     I71   Sales_West_Zone  27/12/2019         99     12   4125.000000
# 29      I34   Sales_West_Zone   21/5/2019         99      5   9900.000000
# 1129    I24  Sales_North_Zone    8/1/2019         99      8   6187.500000
# 230     I59  Sales_North_Zone    9/6/2019         99      9   5500.000000
# 1197    I67   Sales_East_Zone   14/2/2019         99      2  24750.000000
# 876      I3  Sales_South_Zone  27/11/2019         98     11   4454.545455
# ...

# %%
#Top10['Month'].value_counts()
Top10[(Top10['Month']==3) & (data['Advance']==2020)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4932/2946542806.py in <cell line: 2>()
#       1 #Top10['Month'].value_counts()
# ----> 2 Top10[(Top10['Emp_ID'].groupby([Top10['Month']]))]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1307
#    1308         if ax._index_as_unique:
# -> 1309             indexer = ax.get_indexer_for(keyarr)
#    1310             keyarr = ax.reindex(keyarr)[0]
#    1311         else:
#
# ...

# %%
#Top10['additional']= 2000
#print( Top10['Additional_Performance_Bonus'])
if Top10['Month']==3:
    print(Top10['additional'])
else:
    print('null')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4932/3514127102.py in <cell line: 3>()
#       1 #Top10['additional']= 2000
#       2 #print( Top10['Additional_Performance_Bonus'])
# ----> 3 if Top10['Month']==3:
#       4     print(Top10['additional'])
#       5 else:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1535     @final
#    1536     def __nonzero__(self):
# -> 1537         raise ValueError(
#    1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
#Top = Top10.groupby('Emp_ID') &
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4932/474241297.py in <cell line: 3>()
#       1 #Top = Top10.groupby('Emp_ID') &
#       2 #Top10['Month'].value_counts()
# ----> 3 df1['Date'].dt.month.value_counts()             # To show the no. of item occurences in that particular year
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     179             # we're accessing the attribute of the class, i.e., Dataset.geo
#     180             return self._accessor
# --> 181         accessor_obj = self._accessor(obj)
# ...

# %%
Top10
# Out:
#      Emp_ID        Department        Date  Emp_Score  Month          Bonus  \
# 161      I7  Sales_South_Zone   13/5/2019        100      5   20000.000000
# 538     I21   Sales_East_Zone   20/7/2019        100      7   14285.714286
# 770     I88  Sales_South_Zone  26/10/2019        100     10   10000.000000
# 701      I7  Sales_South_Zone  20/11/2019        100     11    9090.909091
# 688     I26   Sales_West_Zone  30/10/2019        100     10   10000.000000
# 1052    I65   Sales_East_Zone   24/2/2019        100      2   50000.000000
# 576      I9  Sales_North_Zone   12/7/2019        100     12    8333.333333
# 1156    I22  Sales_North_Zone   23/1/2019        100      1  100000.000000
# 559     I88  Sales_South_Zone   18/8/2019        100      8   12500.000000
# 761     I55   Sales_West_Zone  10/12/2019        100     10   10000.000000
#
#       additional
# 161         2000
# 538         2000
# 770         2000
# 701         2000
# 688         2000
# 1052        2000
# ...

# %%
sum=0
for i in Top10.columns:
    if Top10['Additional_Performance_Bonus']==2000:
        sum=sum+1
        if sum>=2:
            Top10['Surprise_Bonus']=Top10['Surprise_Bonus'].append([2500])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4932/3950832358.py in <cell line: 2>()
#       1 sum=0
#       2 for i in Top10.columns:
# ----> 3     if Top10['Additional_Performance_Bonus']==2000:
#       4         sum=sum+1
#       5         if sum>=2:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1535     @final
#    1536     def __nonzero__(self):
# -> 1537         raise ValueError(
#    1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
Top10
# Out:
#      Emp_ID        Department        Date  Emp_Score  Month          Bonus  \
# 161      I7  Sales_South_Zone   13/5/2019        100      5   20000.000000
# 538     I21   Sales_East_Zone   20/7/2019        100      7   14285.714286
# 770     I88  Sales_South_Zone  26/10/2019        100     10   10000.000000
# 701      I7  Sales_South_Zone  20/11/2019        100     11    9090.909091
# 688     I26   Sales_West_Zone  30/10/2019        100     10   10000.000000
# 1052    I65   Sales_East_Zone   24/2/2019        100      2   50000.000000
# 576      I9  Sales_North_Zone   12/7/2019        100     12    8333.333333
# 1156    I22  Sales_North_Zone   23/1/2019        100      1  100000.000000
# 559     I88  Sales_South_Zone   18/8/2019        100      8   12500.000000
# 761     I55   Sales_West_Zone  10/12/2019        100     10   10000.000000
#
#       Additional_Performance_Bonus
# 161                   22000.000000
# 538                   16285.714286
# 770                   12000.000000
# ...

# %% [markdown]
# ### Q1. Prepare an excel outcome of following table structure:

# %%
data1 = Top10.drop(['Date'],axis=1)

# %%
data1
# Out:
#      Emp_ID        Department  Emp_Score  Month          Bonus  \
# 161      I7  Sales_South_Zone        100      5   20000.000000
# 538     I21   Sales_East_Zone        100      7   14285.714286
# 770     I88  Sales_South_Zone        100     10   10000.000000
# 701      I7  Sales_South_Zone        100     11    9090.909091
# 688     I26   Sales_West_Zone        100     10   10000.000000
# 1052    I65   Sales_East_Zone        100      2   50000.000000
# 576      I9  Sales_North_Zone        100     12    8333.333333
# 1156    I22  Sales_North_Zone        100      1  100000.000000
# 559     I88  Sales_South_Zone        100      8   12500.000000
# 761     I55   Sales_West_Zone        100     10   10000.000000
#
#       Additional_Performance_Bonus
# 161                   22000.000000
# 538                   16285.714286
# 770                   12000.000000
# 701                   11090.909091
# 688                   12000.000000
# 1052                  52000.000000
# ...

# %% [markdown]
# ### Q2. Calculate net out go of money as Bonus for the company.

# %% [markdown]
# ### Q3. Calculate the amount for Performance Bonus that the company will have to provide on monthly basis on the above given matrix.

# %% [markdown]
# ### Q.4 Find out the department whose employees received the highest Bonus amount for the financial year.

# %%
Data[Data.groupby(['department']).MAX('Budget')

# %% [markdown]
# ### Q5. Find out which are the Top 10 employees based on the Bonus they have received.

# %%
data1['Bonus'].sort().head(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4932/3030634966.py in <cell line: 1>()
# ----> 1 data1['Bonus'].sort().head(10)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'sort'
